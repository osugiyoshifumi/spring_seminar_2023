# %% [markdown]
# # 12：ハイパーパラメータの探索と検証データ
#
#
# ---
# ## 目的
# CNNを用いたMNISTデータセット文字認識を通じて，ハイパーパラメータの探索・検証および検証データの役割について理解する．
#
# また，ここではGPUを用いたネットワークの計算を行う．

# %% [markdown]
# ## 準備
#
# ### Google Colaboratoryの設定確認・変更
# 本チュートリアルではPyTorchを利用してニューラルネットワークの実装を確認，学習および評価を行います．
# **GPUを用いて処理を行うために，上部のメニューバーの「ランタイム」→「ランタイムのタイプを変更」からハードウェアアクセラレータをGPUにしてください．**

# %% [markdown]
# ## モジュールのインポート
# はじめに必要なモジュールをインポートする．
#
# ### GPUの確認
# GPUを使用した計算が可能かどうかを確認します．
#
# `GPU availability: True`と表示されれば，GPUを使用した計算をPyTorchで行うことが可能です．
# Falseとなっている場合は，上記の「Google Colaboratoryの設定確認・変更」に記載している手順にしたがって，設定を変更した後に，モジュールのインポートから始めてください．

# %%
# モジュールのインポート
import os
from time import time
import numpy as np
import torch
import torch.nn as nn

import torchvision
import torchvision.transforms as transforms

import torchsummary

import gzip
from random import randint

import matplotlib.pyplot as plt

# GPUの確認
use_cuda = torch.cuda.is_available()
print('Use CUDA:', use_cuda)
# Out:
# Use CUDA: True

# %% [markdown]
# ## データセットのダウンロードと読み込みと学習サンプルの削減
#
#
# まずはじめに，`wget`コマンドを使用して，MNISTデータセットをダウンロードします．

# %%
# !wget -q http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz -O train-images-idx3-ubyte.gz
# !wget -q http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz -O train-labels-idx1-ubyte.gz
# !wget -q http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz -O t10k-images-idx3-ubyte.gz
# !wget -q http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz -O t10k-labels-idx1-ubyte.gz

# %% [markdown]
# 次に，ダウンロードしたファイルからデータを読み込みます．詳細は前回までのプログラムを確認してください．
#
# 今回は2次元の画像データとしてMNISTデータセットを扱うため，
# データを`(チャンネル, 縦，横)`の形に並べ替えます．

# %%
# load images
with gzip.open('train-images-idx3-ubyte.gz', 'rb') as f:
    x_train = np.frombuffer(f.read(), np.uint8, offset=16)
x_train = x_train.reshape(-1, 784)

with gzip.open('t10k-images-idx3-ubyte.gz', 'rb') as f:
    x_test = np.frombuffer(f.read(), np.uint8, offset=16)
x_test = x_test.reshape(-1, 784)

with gzip.open('train-labels-idx1-ubyte.gz', 'rb') as f:
    y_train = np.frombuffer(f.read(), np.uint8, offset=8)

with gzip.open('t10k-labels-idx1-ubyte.gz', 'rb') as f:
    y_test = np.frombuffer(f.read(), np.uint8, offset=8)

x_train = x_train.reshape(-1, 1, 28, 28)
x_test = x_test.reshape(-1, 1, 28, 28)

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (60000, 1, 28, 28) (60000,)
# (10000, 1, 28, 28) (10000,)

# %% [markdown]
# ## 検証データの作成
#
# ネットワークの学習やモデルの定義には多くのハイパーパラメータが存在します．例えば，
# * ネットワークのハイパーパラメータ
#   * 中間層の層数
#   * 中間層のユニット数
#   * Dropoutを適用するかどうか（Dropoutを用いる場所やdropout ratio）
#   * Batch Normalizationを適用するかどうか
#
# * 学習のハイパーパラメータ
#   * 学習率
#   * 学習回数
#   * ミニバッチサイズ
#
# などが挙げられます．
#
# 最適なハイパーパラメータを決定するために使用するデータを**検証データ（validation data）**と呼びます．
#
# MNISTデータセットには学習データ（train data）とテストデータ（test data）しか存在しません．このように，専用の検証データが存在しないデータセットや個人が作成したオリジナルのデータセットでは，学習データの一部を検証データとして使用します．
#
# 以下では，MNISTデータセットの学習データを分割し，学習および検証データを作成します．
# まず，検証データに使用するデータの割合を`validation_ratio`として定義します．
# 今回は学習データの20%を検証データとして使用することとし，0.2と指定します．
# この割合に基づいて，学習データの20%となるサンプル数を`n_val`として計算します．
#
# その後，学習および検証データになるよう，データを分割します．
#
# 実行すると，60000枚の学習サンプルの20%である12000枚が検証データ，残りの80%の48000枚が学習データになるよう分割されていることがわかります．

# %%
validation_ratio = 0.2   # 検証に使用するデータの割合
n_train_original = x_train.shape[0]
n_val = int(n_train_original * validation_ratio)

# 検証データ
x_val = x_train[0:n_val]
y_val = y_train[0:n_val]

# 学習データ
x_train = x_train[n_val:]
y_train = y_train[n_val:]

print("train      :", x_train.shape, y_train.shape)
print("validation :", x_val.shape, y_val.shape)
print("test       :", x_test.shape, y_test.shape)
# Out:
# train      : (48000, 1, 28, 28) (48000,)
# validation : (12000, 1, 28, 28) (12000,)
# test       : (10000, 1, 28, 28) (10000,)

# %% [markdown]
# ## ネットワークモデルの定義
# 畳み込みニューラルネットワークを定義します．
#
# ここでは，畳み込み層1層，全結合層2層から構成されるネットワークとします．
#
# ここでは，最適なネットワーク構造をハイパーパラメータとして探索するために，ネットワーク構造のパラメータをクラスの引数として定義し，任意のサイズのネットワークを作成できるようにクラス定義を行います．
#
# 1層目の畳み込み層は入力チャンネル数を`in_channels`，出力する特徴マップ数を`out_channels`，畳み込むフィルタサイズを`kernel_size`$\times$`kernel_size`として定義します．
# 1つ目の全結合層は入力ユニット数は畳み込みの特徴マップ数から自動で計算し，出力を`hidden_size`として定義します．
# これらの各層の構成を`__init__`関数で定義します．
#
# 次に，`forward`関数では，定義した層を接続して処理するように記述します．

# %%
class CNN(nn.Module):
    def __init__(self, in_channels=1, out_channels= 64, kernel_size=3, hidden_size=128):
        super().__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, stride=1, padding=1)
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(2, 2)
        self.l1 = nn.Linear(int(28/2) * int(28/2) * out_channels, hidden_size)
        self.l2 = nn.Linear(hidden_size, 10)
    
    def forward(self, x):
        h = self.relu(self.conv(x))
        h = self.pool(h)
        h = h.view(h.size()[0], -1)
        h = self.relu(self.l1(h))
        h = self.l2(h)
        return h

# %% [markdown]
# ## 学習およびハイパーパラメータ探索の準備

# %% [markdown]
# ### 探索時に共通するパラメータの設定
#
# まずはじめに，探索時に共通するパラメータを定義します．
# 具体的には，入力層のユニット数`input_size`および出力層のユニット数`output_size`は，探索時には共通であるため，事前に定義しておきます．
# また，学習，検証データのサンプル数もすでに決まっているため，変数として定義しておきます．

# %%
input_size = x_train.shape[1]
output_size = 10

num_train_data = x_train.shape[0]
num_val_data = x_val.shape[0]
num_test_data = x_test.shape[0]

# %% [markdown]
# ### 探索するパラメータの設定
#
# 次に，検証データを用いて最適な値を求めたいパラメータを定義します．
#
# ここでは，畳み込み層のチャンネル数（``）のユニット数の最適な値を`channel_list = [32, 64, 128, 256]`の中から求めるものとし，他のパラメータは固定します．
#
# **下部にある課題ではその他のパラメータを探索しますが，その他のパラメータをリストとして定義して，探索しましょう．**
#
# また，パラメータの探索には複数回の学習を行う必要があり計算に多くの時間を要します．
# ここでは，実習中の計算時間削減のために，学習エポック数を10と小さい値に設定します．

# %%
n_hidden = 64
n_hidden_list = [16, 32, 64, 128, 256]

channel_size = 64
#channel_list = [32, 64, 128, 256]

batch_size = 100
n_iter = num_train_data / batch_size

learning_rate = 0.01
# learning_rate_list = [0.1, 0.05, 0.01, 0.005, 0.001]

epoch_num = 10

learning_rate = 0.01

# %% [markdown]
# ## ハイパーパラメータ探索
#
# ハイパーパラメータ探索を行います．
#
# まず，各パラメータでの結果を保存するためのリスト`param_search_list`を作成します．
#
# 次に，for文を用いて探索したいハイパーパラメータを一つづつ指定し，ネットワークの学習と検証データでの精度を求めます．
# ネットワークの学習プログラムは前回までのもの同様のため詳細は割愛します．
#
# 学習が終了すると，探索したパラメータの値やその時の誤差および精度の推移のデータを辞書型オブジェクト`result`に格納し，それを`param_search_list`に保存します．
#
# これを繰り返すことで，各パラメータの値を用いた場合の精度や学習推移を確認比較することが可能となり，より精度の高いネットワークを構築するためのあたりをつけることができます．

# %%
param_search_list = []

# 誤差関数の設定
criterion = nn.CrossEntropyLoss()
if use_cuda:
    criterion.cuda()

for n_hidden in n_hidden_list:
    model = CNN(out_channels=channel_size, hidden_size=n_hidden)
    if use_cuda:
        model.cuda()

    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)

    epoch_list = []
    train_loss_list = []
    train_accuracy_list = []
    val_accuracy_list = []

    # ネットワークを学習モードへ変更
    model.train()

    iteration = 1
    for epoch in range(1, epoch_num+1):
        count, sum_loss = 0.0, 0.0
        
        perm = np.random.permutation(num_train_data)
        for i in range(0, num_train_data, batch_size):
            x_batch = x_train[perm[i:i+batch_size]]
            y_batch = y_train[perm[i:i+batch_size]]

            x_batch = torch.from_numpy(x_batch).type(torch.float32)
            y_batch = torch.from_numpy(y_batch).type(torch.int64)

            if use_cuda:
                x_batch = x_batch.cuda()
                y_batch = y_batch.cuda()

            y = model(x_batch)

            loss = criterion(y, y_batch)
            
            model.zero_grad()
            loss.backward()
            optimizer.step()

            sum_loss += loss.item()
            pred = torch.argmax(y, dim=1)
            count += torch.sum(pred == y_batch)

            iteration += 1
            
        # 検証データでの精度の確認
        val_correct_count = 0
        for i in range(num_val_data):
            input = x_val[i:i+1]
            label = y_val[i:i+1]
            input = torch.from_numpy(input).type(torch.float32)
            label = torch.from_numpy(label).type(torch.int64)
            if use_cuda:
                input = input.cuda()
                label = label.cuda()
            y = model(input)
            pred = torch.argmax(y)
            if pred == label:
              val_correct_count += 1

        # 学習途中のlossと精度の保存
        epoch_list.append(epoch)
        train_loss_list.append(sum_loss / num_train_data)
        train_accuracy_list.append(count / num_train_data)
        val_accuracy_list.append(val_correct_count / num_val_data)
            
        print("epoch: {}, mean loss: {}, mean accuracy: {}".format(epoch,
                                                                  sum_loss / n_iter,
                                                                  count.item() / num_train_data))

# epoch: 5, mean loss: 0.0875119474469102, mean accuracy: 0.9737291666666666
# epoch: 6, mean loss: 0.1012390110171206, mean accuracy: 0.9717708333333334
# epoch: 7, mean loss: 0.08131155949007128, mean accuracy: 0.9770416666666667
# epoch: 8, mean loss: 0.07694881501041285, mean accuracy: 0.9781875
# epoch: 9, mean loss: 0.09044434277214654, mean accuracy: 0.9777083333333333
# epoch: 10, mean loss: 0.0971821397576908, mean accuracy: 0.9765416666666666
# 0.01 64 tensor(0.9765, device='cuda:0') 0.9586666666666667
# epoch: 1, mean loss: 8.402659752902885, mean accuracy: 0.6769166666666667
# epoch: 2, mean loss: 0.41323686987161634, mean accuracy: 0.8698333333333333
# epoch: 3, mean loss: 0.3589963411912322, mean accuracy: 0.8865625
# epoch: 4, mean loss: 0.31649536766732733, mean accuracy: 0.8985833333333333
# epoch: 5, mean loss: 0.29238720041078825, mean accuracy: 0.9057291666666667
# epoch: 6, mean loss: 0.2625276353520652, mean accuracy: 0.9162291666666667
# epoch: 7, mean loss: 0.2508899594967564, mean accuracy: 0.9188958333333334
# epoch: 8, mean loss: 0.2428876711210857, mean accuracy: 0.9209791666666667
# epoch: 9, mean loss: 0.23325166481857498, mean accuracy: 0.9248125
# epoch: 10, mean loss: 0.2198178138739119, mean accuracy: 0.9292083333333333
# 0.01 64 tensor(0.9292, device='cuda:0') 0.92325

# %% [markdown]
# ## 探索結果の確認
#
# `param_search_list`に保存しておいた各ハイパーパラメータに対する結果を確認します．
#
# まず，各結果の数値をprintします．
# その後，各パラメータでの学習推移（検証データ）をプロットし比較します．

# %%
# 学習結果の表示
for ps in param_search_list:
    print("lr:", ps['lr'],
          "channel size", ps['channel_size'],
          "train accuracy:", ps['train_acc'][-1],
          "validation accuracy:", ps['val_acc'][-1])

# グラフプロット
plt.figure()
for ps in param_search_list:
    plt.plot(ps['val_acc'], label='ch. size=%d' % ps['channel_size'])
plt.xlabel("epoch")     # x軸ラベル
plt.ylabel("accuracy")  # y軸ラベル
plt.legend()            # 凡例
plt.show()
# Out:
# lr: 0.01 channel size 64 train accuracy: tensor(0.9291, device='cuda:0') validation accuracy: 0.9375
# lr: 0.01 channel size 64 train accuracy: tensor(0.9179, device='cuda:0') validation accuracy: 0.8875833333333333
# lr: 0.01 channel size 64 train accuracy: tensor(0.9017, device='cuda:0') validation accuracy: 0.9014166666666666
# lr: 0.01 channel size 64 train accuracy: tensor(0.9765, device='cuda:0') validation accuracy: 0.9586666666666667
# lr: 0.01 channel size 64 train accuracy: tensor(0.9292, device='cuda:0') validation accuracy: 0.92325

# %% [markdown]
# ## 課題
# 1. 他のパラメータについても探索をして最適な値を見つけよう
# 2. 複数種類のパラメータの最適な組み合わせを求めよう

# %%
n_hidden = 64
#n_hidden_list = [16, 32, 64, 128, 256]

#channel_size = 64
channel_list = [32, 64, 128, 256]

batch_size = 100
n_iter = num_train_data / batch_size

learning_rate = 0.01
# learning_rate_list = [0.1, 0.05, 0.01, 0.005, 0.001]

epoch_num = 10

learning_rate = 0.01

param_search_list = []

# 誤差関数の設定
criterion = nn.CrossEntropyLoss()
if use_cuda:
    criterion.cuda()

for channel_size in channel_list:
    model = CNN(out_channels=channel_size, hidden_size=n_hidden)
    if use_cuda:
        model.cuda()

    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)

    epoch_list = []
    train_loss_list = []
    train_accuracy_list = []
    val_accuracy_list = []

    # ネットワークを学習モードへ変更
    model.train()

    iteration = 1
    for epoch in range(1, epoch_num+1):
        count, sum_loss = 0.0, 0.0
        
        perm = np.random.permutation(num_train_data)
        for i in range(0, num_train_data, batch_size):
            x_batch = x_train[perm[i:i+batch_size]]
            y_batch = y_train[perm[i:i+batch_size]]

            x_batch = torch.from_numpy(x_batch).type(torch.float32)
            y_batch = torch.from_numpy(y_batch).type(torch.int64)

            if use_cuda:
                x_batch = x_batch.cuda()
                y_batch = y_batch.cuda()

            y = model(x_batch)

            loss = criterion(y, y_batch)
            
            model.zero_grad()
            loss.backward()
            optimizer.step()

            sum_loss += loss.item()
            pred = torch.argmax(y, dim=1)
            count += torch.sum(pred == y_batch)

            iteration += 1
            
        # 検証データでの精度の確認
        val_correct_count = 0
        for i in range(num_val_data):
            input = x_val[i:i+1]
            label = y_val[i:i+1]
            input = torch.from_numpy(input).type(torch.float32)
            label = torch.from_numpy(label).type(torch.int64)
            if use_cuda:
                input = input.cuda()
                label = label.cuda()
            y = model(input)
            pred = torch.argmax(y)
            if pred == label:
              val_correct_count += 1

        # 学習途中のlossと精度の保存
        epoch_list.append(epoch)
        train_loss_list.append(sum_loss / num_train_data)
        train_accuracy_list.append(count / num_train_data)
        val_accuracy_list.append(val_correct_count / num_val_data)
            
        print("epoch: {}, mean loss: {}, mean accuracy: {}".format(epoch,
                                                                  sum_loss / n_iter,
                                                                  count.item() / num_train_data))

    # 探索した結果の保存
    result = {'lr': learning_rate, 'channel_size': channel_size,
              'val_acc': val_accuracy_list,
              'train_acc': train_accuracy_list,
              'train_loss': train_loss_list}
    param_search_list.append(result)
    print(result['lr'], result['channel_size'], result['train_acc'][-1], result['val_acc'][-1])

# 学習結果の表示
for ps in param_search_list:
    print("lr:", ps['lr'],
          "channel size", ps['channel_size'],
          "train accuracy:", ps['train_acc'][-1],
          "validation accuracy:", ps['val_acc'][-1])

# グラフプロット
plt.figure()
for ps in param_search_list:
    plt.plot(ps['val_acc'], label='ch. size=%d' % ps['channel_size'])
plt.xlabel("epoch")     # x軸ラベル
plt.ylabel("accuracy")  # y軸ラベル
plt.legend()            # 凡例
plt.show()
# Out:
# epoch: 1, mean loss: 2.9827579743539294, mean accuracy: 0.67875
# epoch: 2, mean loss: 0.457264473879089, mean accuracy: 0.8598541666666667
# epoch: 3, mean loss: 0.4004276782584687, mean accuracy: 0.8758958333333333
# epoch: 4, mean loss: 0.3808231510221958, mean accuracy: 0.882
# epoch: 5, mean loss: 0.3740600920903186, mean accuracy: 0.883125
# epoch: 6, mean loss: 0.3631892517829935, mean accuracy: 0.8848333333333334
# epoch: 7, mean loss: 0.3482822317009171, mean accuracy: 0.8910208333333334
# epoch: 8, mean loss: 0.34415566399693487, mean accuracy: 0.8912291666666666
# epoch: 9, mean loss: 0.33476566687847176, mean accuracy: 0.8945416666666667
train accuracy: tensor(0.1123, device='cuda:0') validation accuracy: 0.11258333333333333

# %%
n_hidden = 64
#n_hidden_list = [16, 32, 64, 128, 256]

channel_size = 64
#channel_list = [32, 64, 128, 256]

batch_size = 100
n_iter = num_train_data / batch_size

#learning_rate = 0.01
learning_rate_list = [0.1, 0.05, 0.01, 0.005, 0.001]

epoch_num = 10

learning_rate = 0.01

param_search_list = []

# 誤差関数の設定
criterion = nn.CrossEntropyLoss()
if use_cuda:
    criterion.cuda()

for learning_rate in learning_rate_list:
    model = CNN(out_channels=channel_size, hidden_size=n_hidden)
    if use_cuda:
        model.cuda()

    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)

    epoch_list = []
    train_loss_list = []
    train_accuracy_list = []
    val_accuracy_list = []

    # ネットワークを学習モードへ変更
    model.train()

    iteration = 1
    for epoch in range(1, epoch_num+1):
        count, sum_loss = 0.0, 0.0
        
        perm = np.random.permutation(num_train_data)
        for i in range(0, num_train_data, batch_size):
            x_batch = x_train[perm[i:i+batch_size]]
            y_batch = y_train[perm[i:i+batch_size]]

            x_batch = torch.from_numpy(x_batch).type(torch.float32)
            y_batch = torch.from_numpy(y_batch).type(torch.int64)

            if use_cuda:
                x_batch = x_batch.cuda()
                y_batch = y_batch.cuda()

            y = model(x_batch)

            loss = criterion(y, y_batch)
            
            model.zero_grad()
            loss.backward()
            optimizer.step()

            sum_loss += loss.item()
            pred = torch.argmax(y, dim=1)
            count += torch.sum(pred == y_batch)

            iteration += 1
            
        # 検証データでの精度の確認
        val_correct_count = 0
        for i in range(num_val_data):
            input = x_val[i:i+1]
            label = y_val[i:i+1]
            input = torch.from_numpy(input).type(torch.float32)
            label = torch.from_numpy(label).type(torch.int64)
            if use_cuda:
                input = input.cuda()
                label = label.cuda()
            y = model(input)
            pred = torch.argmax(y)
            if pred == label:
              val_correct_count += 1

        # 学習途中のlossと精度の保存
        epoch_list.append(epoch)
        train_loss_list.append(sum_loss / num_train_data)
        train_accuracy_list.append(count / num_train_data)
        val_accuracy_list.append(val_correct_count / num_val_data)
            
        print("epoch: {}, mean loss: {}, mean accuracy: {}".format(epoch,
                                                                  sum_loss / n_iter,
                                                                  count.item() / num_train_data))

    # 探索した結果の保存
    result = {'lr': learning_rate, 'channel_size': channel_size,
              'val_acc': val_accuracy_list,
              'train_acc': train_accuracy_list,
              'train_loss': train_loss_list}
    param_search_list.append(result)
    print(result['lr'], result['channel_size'], result['train_acc'][-1], result['val_acc'][-1])

# 学習結果の表示
for ps in param_search_list:
    print("lr:", ps['lr'],
          "channel size", ps['channel_size'],
          "train accuracy:", ps['train_acc'][-1],
          "validation accuracy:", ps['val_acc'][-1])

# グラフプロット
plt.figure()
for ps in param_search_list:
    plt.plot(ps['val_acc'], label='ch. size=%d' % ps['channel_size'])
plt.xlabel("epoch")     # x軸ラベル
plt.ylabel("accuracy")  # y軸ラベル
plt.legend()            # 凡例
plt.show()
# Out:
# epoch: 1, mean loss: 90.06929305742185, mean accuracy: 0.10622916666666667
# epoch: 2, mean loss: 2.3033259600400924, mean accuracy: 0.10825
# epoch: 3, mean loss: 2.303590162595113, mean accuracy: 0.10752083333333333
# epoch: 4, mean loss: 2.3034798090656596, mean accuracy: 0.10775
# epoch: 5, mean loss: 2.3036437034606934, mean accuracy: 0.10645833333333334
# epoch: 2, mean loss: 0.0766364637723503, mean accuracy: 0.9771458333333334
# epoch: 3, mean loss: 0.05484924393628413, mean accuracy: 0.983125
# epoch: 4, mean loss: 0.040893779686787944, mean accuracy: 0.987375
# epoch: 5, mean loss: 0.03249571740695198, mean accuracy: 0.9900416666666667
# epoch: 6, mean loss: 0.02658136572317744, mean accuracy: 0.9912916666666667
# epoch: 7, mean loss: 0.019291640189961375, mean accuracy: 0.9940208333333334
# epoch: 8, mean loss: 0.014620271643555801, mean accuracy: 0.9958958333333333
# epoch: 9, mean loss: 0.011081480601145206, mean accuracy: 0.9969583333333333
# epoch: 10, mean loss: 0.008495827651131549, mean accuracy: 0.9978125
# 0.001 64 tensor(0.9978, device='cuda:0') 0.97925
# lr: 0.1 channel size 64 train accuracy: tensor(0.1049, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 64 train accuracy: tensor(0.1089, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.01 channel size 64 train accuracy: tensor(0.9604, device='cuda:0') validation accuracy: 0.9223333333333333
# lr: 0.005 channel size 64 train accuracy: tensor(0.9827, device='cuda:0') validation accuracy: 0.968
# lr: 0.001 channel size 64 train accuracy: tensor(0.9978, device='cuda:0') validation accuracy: 0.97925

# %%
#n_hidden = 64
n_hidden_list = [16, 32, 64, 128, 256]

#channel_size = 64
channel_list = [32, 64, 128, 256]

batch_size = 100
n_iter = num_train_data / batch_size

#learning_rate = 0.01
learning_rate_list = [0.1, 0.05, 0.01, 0.005, 0.001]

epoch_num = 10

learning_rate = 0.01

param_search_list = []

# 誤差関数の設定
criterion = nn.CrossEntropyLoss()
if use_cuda:
    criterion.cuda()

for learning_rate in learning_rate_list:
    for n_hidden in n_hidden_list:
        for channel_size in channel_list:
                model = CNN(out_channels=channel_size, hidden_size=n_hidden)
                if use_cuda:
                    model.cuda()

                optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)

                epoch_list = []
                train_loss_list = []
                train_accuracy_list = []
                val_accuracy_list = []

                # ネットワークを学習モードへ変更
                model.train()

                iteration = 1
                for epoch in range(1, epoch_num+1):
                    count, sum_loss = 0.0, 0.0
        
                    perm = np.random.permutation(num_train_data)
                    for i in range(0, num_train_data, batch_size):
                        x_batch = x_train[perm[i:i+batch_size]]
                        y_batch = y_train[perm[i:i+batch_size]]

                        x_batch = torch.from_numpy(x_batch).type(torch.float32)
                        y_batch = torch.from_numpy(y_batch).type(torch.int64)

                        if use_cuda:
                            x_batch = x_batch.cuda()
                            y_batch = y_batch.cuda()

                        y = model(x_batch)

                        loss = criterion(y, y_batch)
            
                        model.zero_grad()
                        loss.backward()
                        optimizer.step()

                        sum_loss += loss.item()
                        pred = torch.argmax(y, dim=1)
                        count += torch.sum(pred == y_batch)

                        iteration += 1
            
                    # 検証データでの精度の確認
                    val_correct_count = 0
                    for i in range(num_val_data):
                        input = x_val[i:i+1]
                        label = y_val[i:i+1]
                        input = torch.from_numpy(input).type(torch.float32)
                        label = torch.from_numpy(label).type(torch.int64)
                        if use_cuda:
                            input = input.cuda()
                            label = label.cuda()
                        y = model(input)
                        pred = torch.argmax(y)
                        if pred == label:
                            val_correct_count += 1

                    # 学習途中のlossと精度の保存
                    epoch_list.append(epoch)
                    train_loss_list.append(sum_loss / num_train_data)
                    train_accuracy_list.append(count / num_train_data)
                    val_accuracy_list.append(val_correct_count / num_val_data)
            
                    print("epoch: {}, mean loss: {}, mean accuracy: {}".format(epoch,
                                                                            sum_loss / n_iter,
                                                                            count.item() / num_train_data))

                # 探索した結果の保存
                result = {'lr': learning_rate, 'channel_size': channel_size,
                        'val_acc': val_accuracy_list,
                        'train_acc': train_accuracy_list,
                        'train_loss': train_loss_list}
                param_search_list.append(result)
                print(result['lr'], result['channel_size'], result['train_acc'][-1], result['val_acc'][-1])

                # 学習結果の表示
                for ps in param_search_list:
                    print("lr:", ps['lr'],
                    "channel size", ps['channel_size'],
                    "train accuracy:", ps['train_acc'][-1],
                    "validation accuracy:", ps['val_acc'][-1])

# グラフプロット
plt.figure()
for ps in param_search_list:
    plt.plot(ps['val_acc'], label='ch. size=%d' % ps['channel_size'])
plt.xlabel("epoch")     # x軸ラベル
plt.ylabel("accuracy")  # y軸ラベル
plt.legend()            # 凡例
plt.show()
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# lr: 0.05 channel size 64 train accuracy: tensor(0.1097, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 128 train accuracy: tensor(0.1095, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 256 train accuracy: tensor(0.0983, device='cuda:0') validation accuracy: 0.1005
# lr: 0.05 channel size 32 train accuracy: tensor(0.1114, device='cuda:0') validation accuracy: 0.10658333333333334
# lr: 0.05 channel size 64 train accuracy: tensor(0.1097, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 128 train accuracy: tensor(0.1114, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 256 train accuracy: tensor(0.1107, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 32 train accuracy: tensor(0.1091, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 64 train accuracy: tensor(0.1096, device='cuda:0') validation accuracy: 0.10658333333333334
# epoch: 1, mean loss: 38208967.35620851, mean accuracy: 0.10895833333333334
# epoch: 2, mean loss: 2.3024492517113684, mean accuracy: 0.1101875
# epoch: 3, mean loss: 2.302654890716076, mean accuracy: 0.1100625
# epoch: 4, mean loss: 2.3023296559850377, mean accuracy: 0.10883333333333334
# epoch: 5, mean loss: 2.3024001494050026, mean accuracy: 0.10829166666666666
# epoch: 6, mean loss: 2.3025313526391984, mean accuracy: 0.10870833333333334
# epoch: 7, mean loss: 2.302388114233812, mean accuracy: 0.11085416666666667
# epoch: 8, mean loss: 2.3025132472316425, mean accuracy: 0.10897916666666667
# epoch: 9, mean loss: 2.3025417695442836, mean accuracy: 0.1108125
# epoch: 10, mean loss: 2.302497385442257, mean accuracy: 0.11039583333333333
# 0.05 128 tensor(0.1104, device='cuda:0') 0.10658333333333334
# lr: 0.1 channel size 32 train accuracy: tensor(0.1069, device='cuda:0') validation accuracy: 0.09941666666666667
# lr: 0.1 channel size 64 train accuracy: tensor(0.1067, device='cuda:0') validation accuracy: 0.10233333333333333
# lr: 0.1 channel size 128 train accuracy: tensor(0.1091, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 256 train accuracy: tensor(0.1058, device='cuda:0') validation accuracy: 0.10658333333333334
# lr: 0.1 channel size 32 train accuracy: tensor(0.1067, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 64 train accuracy: tensor(0.1088, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 128 train accuracy: tensor(0.1079, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 256 train accuracy: tensor(0.1067, device='cuda:0') validation accuracy: 0.10658333333333334
# lr: 0.1 channel size 32 train accuracy: tensor(0.1067, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 64 train accuracy: tensor(0.1056, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 128 train accuracy: tensor(0.1086, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 256 train accuracy: tensor(0.1080, device='cuda:0') validation accuracy: 0.10233333333333333
# lr: 0.1 channel size 32 train accuracy: tensor(0.1061, device='cuda:0') validation accuracy: 0.10233333333333333
# lr: 0.1 channel size 64 train accuracy: tensor(0.1079, device='cuda:0') validation accuracy: 0.10658333333333334
# lr: 0.1 channel size 128 train accuracy: tensor(0.1078, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 256 train accuracy: tensor(0.1056, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 32 train accuracy: tensor(0.1074, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 64 train accuracy: tensor(0.1087, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 128 train accuracy: tensor(0.1072, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 256 train accuracy: tensor(0.0983, device='cuda:0') validation accuracy: 0.1005
# lr: 0.05 channel size 32 train accuracy: tensor(0.1101, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 64 train accuracy: tensor(0.1083, device='cuda:0') validation accuracy: 0.098
# lr: 0.05 channel size 128 train accuracy: tensor(0.1101, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 256 train accuracy: tensor(0.1085, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 32 train accuracy: tensor(0.1110, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 64 train accuracy: tensor(0.1111, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 128 train accuracy: tensor(0.1088, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 256 train accuracy: tensor(0.1110, device='cuda:0') validation accuracy: 0.10658333333333334
# lr: 0.05 channel size 32 train accuracy: tensor(0.1112, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 64 train accuracy: tensor(0.1097, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 128 train accuracy: tensor(0.1095, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 256 train accuracy: tensor(0.0983, device='cuda:0') validation accuracy: 0.1005
# lr: 0.05 channel size 32 train accuracy: tensor(0.1114, device='cuda:0') validation accuracy: 0.10658333333333334
# lr: 0.05 channel size 64 train accuracy: tensor(0.1097, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 128 train accuracy: tensor(0.1114, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 256 train accuracy: tensor(0.1107, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 32 train accuracy: tensor(0.1091, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 64 train accuracy: tensor(0.1096, device='cuda:0') validation accuracy: 0.10658333333333334
# lr: 0.05 channel size 128 train accuracy: tensor(0.1104, device='cuda:0') validation accuracy: 0.10658333333333334
# epoch: 1, mean loss: 8384553.712481204, mean accuracy: 0.10952083333333333
# epoch: 2, mean loss: 2.3026153271396956, mean accuracy: 0.10977083333333333
# epoch: 3, mean loss: 2.302326420942942, mean accuracy: 0.10985416666666667
# epoch: 4, mean loss: 2.302346290151278, mean accuracy: 0.11072916666666667
# epoch: 5, mean loss: 2.302460898955663, mean accuracy: 0.10895833333333334
# epoch: 6, mean loss: 2.3026104902227718, mean accuracy: 0.10975
# epoch: 7, mean loss: 2.3022610659400624, mean accuracy: 0.11116666666666666
# epoch: 8, mean loss: 2.3025084644556046, mean accuracy: 0.1101875
# epoch: 9, mean loss: 2.3025525247057277, mean accuracy: 0.11075
# epoch: 10, mean loss: 2.3026218096415203, mean accuracy: 0.10902083333333333
# 0.05 256 tensor(0.1090, device='cuda:0') 0.11258333333333333
# lr: 0.1 channel size 32 train accuracy: tensor(0.
333333
# lr: 0.01 channel size 64 train accuracy: tensor(0.9518, device='cuda:0') validation accuracy: 0.9335833333333333
# epoch: 1, mean loss: 8.056866977068905, mean accuracy: 0.8525625
# epoch: 2, mean loss: 0.27436329529931147, mean accuracy: 0.9200833333333334
# epoch: 3, mean loss: 0.23620047145911183, mean accuracy: 0.9324583333333333
# epoch: 4, mean loss: 0.2066672372437703, mean accuracy: 0.9432916666666666
# epoch: 5, mean loss: 0.1787385097006336, mean accuracy: 0.9514583333333333
# epoch: 6, mean loss: 0.16496646234105963, mean accuracy: 0.9546458333333333
# epoch: 7, mean loss: 0.16031676217583785, mean accuracy: 0.956375
# epoch: 8, mean loss: 0.14109820519758312, mean accuracy: 0.9618958333333333
# epoch: 9, mean loss: 0.14645560559001752, mean accuracy: 0.9595833333333333
# epoch: 10, mean loss: 0.14436158464717058, mean accuracy: 0.9610416666666667
# 0.01 128 tensor(0.9610, device='cuda:0') 0.9411666666666667
# lr: 0.1 channel size 32 train accuracy: tensor(0.1069, device='cuda:0') validation accuracy: 0.09941666666666667
# lr: 0.1 channel size 64 train accuracy: tensor(0.1067, device='cuda:0') validation accuracy: 0.10233333333333333
# lr: 0.1 channel size 128 train accuracy: tensor(0.1091, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 256 train accuracy: tensor(0.1058, device='cuda:0') validation accuracy: 0.10658333333333334
# lr: 0.1 channel size 32 train accuracy: tensor(0.1067, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 64 train accuracy: tensor(0.1088, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 128 train accuracy: tensor(0.1079, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 256 train accuracy: tensor(0.1067, device='cuda:0') validation accuracy: 0.10658333333333334
# lr: 0.1 channel size 32 train accuracy: tensor(0.1067, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 64 train accuracy: tensor(0.1056, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 128 train accuracy: tensor(0.1086, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 256 train accuracy: tensor(0.1080, device='cuda:0') validation accuracy: 0.10233333333333333
# lr: 0.1 channel size 32 train accuracy: tensor(0.1061, device='cuda:0') validation accuracy: 0.10233333333333333
# ...
# lr: 0.005 channel size 256 train accuracy: tensor(0.1123, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.005 channel size 32 train accuracy: tensor(0.9347, device='cuda:0') validation accuracy: 0.9235
# lr: 0.005 channel size 64 train accuracy: tensor(0.9783, device='cuda:0') validation accuracy: 0.96
# lr: 0.005 channel size 128 train accuracy: tensor(0.9682, device='cuda:0') validation accuracy: 0.9555833333333333
# lr: 0.005 channel size 256 train accuracy: tensor(0.9819, device='cuda:0') validation accuracy: 0.9633333333333334
# lr: 0.005 channel size 32 train accuracy: tensor(0.9656, device='cuda:0') validation accuracy: 0.9531666666666667
# lr: 0.005 channel size 64 train accuracy: tensor(0.9744, device='cuda:0') validation accuracy: 0.9610833333333333
# lr: 0.005 channel size 128 train accuracy: tensor(0.9875, device='cuda:0') validation accuracy: 0.9693333333333334
# lr: 0.005 channel size 256 train accuracy: tensor(0.9845, device='cuda:0') validation accuracy: 0.9671666666666666
# lr: 0.005 channel size 32 train accuracy: tensor(0.9894, device='cuda:0') validation accuracy: 0.9706666666666667
# lr: 0.005 channel size 64 train accuracy: tensor(0.9771, device='cuda:0') validation accuracy: 0.9595
# lr: 0.005 channel size 128 train accuracy: tensor(0.9935, device='cuda:0') validation accuracy: 0.9756666666666667
# lr: 0.005 channel size 256 train accuracy: tensor(0.9910, device='cuda:0') validation accuracy: 0.9694166666666667
# lr: 0.005 channel size 32 train accuracy: tensor(0.9910, device='cuda:0') validation accuracy: 0.9721666666666666
# lr: 0.005 channel size 64 train accuracy: tensor(0.9959, device='cuda:0') validation accuracy: 0.9785
# lr: 0.005 channel size 128 train accuracy: tensor(0.9845, device='cuda:0') validation accuracy: 0.96325
# lr: 0.005 channel size 256 train accuracy: tensor(0.9969, device='cuda:0') validation accuracy: 0.9719166666666667
# lr: 0.001 channel size 32 train accuracy: tensor(0.1123, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.001 channel size 64 train accuracy: tensor(0.8617, device='cuda:0') validation accuracy: 0.87825
# lr: 0.001 channel size 128 train accuracy: tensor(0.1123, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.001 channel size 256 train accuracy: tensor(0.9478, device='cuda:0') validation accuracy: 0.92075
# lr: 0.001 channel size 32 train accuracy: tensor(0.9925, device='cuda:0') validation accuracy: 0.974
# lr: 0.001 channel size 64 train accuracy: tensor(0.9979, device='cuda:0') validation accuracy: 0.97825
# lr: 0.001 channel size 128 train accuracy: tensor(0.9937, device='cuda:0') validation accuracy: 0.9720833333333333
# lr: 0.001 channel size 256 train accuracy: tensor(0.9997, device='cuda:0') validation accuracy: 0.9793333333333333
# lr: 0.001 channel size 32 train accuracy: tensor(0.9975, device='cuda:0') validation accuracy: 0.9784166666666667
# lr: 0.001 channel size 64 train accuracy: tensor(0.9974, device='cuda:0') validation accuracy: 0.97675
# lr: 0.001 channel size 128 train accuracy: tensor(0.9998, device='cuda:0') validation accuracy: 0.9819166666666667
# lr: 0.001 channel size 256 train accuracy: tensor(0.9999, device='cuda:0') validation accuracy: 0.9796666666666667
# lr: 0.001 channel size 32 train accuracy: tensor(0.9995, device='cuda:0') validation accuracy: 0.9805833333333334
# lr: 0.001 channel size 64 train accuracy: tensor(1.0000, device='cuda:0') validation accuracy: 0.98375
# lr: 0.001 channel size 128 train accuracy: tensor(0.9999, device='cuda:0') validation accuracy: 0.982
# lr: 0.001 channel size 256 train accuracy: tensor(1., device='cuda:0') validation accuracy: 0.9826666666666667
# lr: 0.001 channel size 32 train accuracy: tensor(1., device='cuda:0') validation accuracy: 0.9834166666666667
# lr: 0.001 channel size 64 train accuracy: tensor(1., device='cuda:0') validation accuracy: 0.98375
# lr: 0.001 channel size 128 train accuracy: tensor(1., device='cuda:0') validation accuracy: 0.9850833333333333
# epoch: 1, mean loss: 22.807143068816124, mean accuracy: 0.9315833333333333
# epoch: 2, mean loss: 0.050785975380373806, mean accuracy: 0.9843958333333334
# epoch: 3, mean loss: 0.02504024327196627, mean accuracy: 0.99275
# epoch: 4, mean loss: 0.015044743372224426, mean accuracy: 0.9958333333333333
# epoch: 5, mean loss: 0.006751881156408975, mean accuracy: 0.9985833333333334
# epoch: 6, mean loss: 0.0034206996289261344, mean accuracy: 0.9995
# epoch: 7, mean loss: 0.0018278136186988074, mean accuracy: 0.9999583333333333
# epoch: 8, mean loss: 0.0011945281210197815, mean accuracy: 1.0
# epoch: 9, mean loss: 0.0009110660235819523, mean accuracy: 1.0
# epoch: 10, mean loss: 0.0007461548483509735, mean accuracy: 1.0
# 0.001 256 tensor(1., device='cuda:0') 0.9844166666666667
# lr: 0.1 channel size 32 train accuracy: tensor(0.1069, device='cuda:0') validation accuracy: 0.09941666666666667
# lr: 0.1 channel size 64 train accuracy: tensor(0.1067, device='cuda:0') validation accuracy: 0.10233333333333333
# lr: 0.1 channel size 128 train accuracy: tensor(0.1091, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 256 train accuracy: tensor(0.1058, device='cuda:0') validation accuracy: 0.10658333333333334
# lr: 0.1 channel size 32 train accuracy: tensor(0.1067, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 64 train accuracy: tensor(0.1088, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 128 train accuracy: tensor(0.1079, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 256 train accuracy: tensor(0.1067, device='cuda:0') validation accuracy: 0.10658333333333334
# lr: 0.1 channel size 32 train accuracy: tensor(0.1067, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 64 train accuracy: tensor(0.1056, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 128 train accuracy: tensor(0.1086, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 256 train accuracy: tensor(0.1080, device='cuda:0') validation accuracy: 0.10233333333333333
# lr: 0.1 channel size 32 train accuracy: tensor(0.1061, device='cuda:0') validation accuracy: 0.10233333333333333
# lr: 0.1 channel size 64 train accuracy: tensor(0.1079, device='cuda:0') validation accuracy: 0.10658333333333334
# lr: 0.1 channel size 128 train accuracy: tensor(0.1078, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 256 train accuracy: tensor(0.1056, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 32 train accuracy: tensor(0.1074, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 64 train accuracy: tensor(0.1087, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 128 train accuracy: tensor(0.1072, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.1 channel size 256 train accuracy: tensor(0.0983, device='cuda:0') validation accuracy: 0.1005
# lr: 0.05 channel size 32 train accuracy: tensor(0.1101, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 64 train accuracy: tensor(0.1083, device='cuda:0') validation accuracy: 0.098
# lr: 0.05 channel size 128 train accuracy: tensor(0.1101, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 256 train accuracy: tensor(0.1085, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 32 train accuracy: tensor(0.1110, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 64 train accuracy: tensor(0.1111, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 128 train accuracy: tensor(0.1088, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 256 train accuracy: tensor(0.1110, device='cuda:0') validation accuracy: 0.10658333333333334
# lr: 0.05 channel size 32 train accuracy: tensor(0.1112, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 64 train accuracy: tensor(0.1097, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 128 train accuracy: tensor(0.1095, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 256 train accuracy: tensor(0.0983, device='cuda:0') validation accuracy: 0.1005
# lr: 0.05 channel size 32 train accuracy: tensor(0.1114, device='cuda:0') validation accuracy: 0.10658333333333334
# lr: 0.05 channel size 64 train accuracy: tensor(0.1097, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 128 train accuracy: tensor(0.1114, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 256 train accuracy: tensor(0.1107, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 32 train accuracy: tensor(0.1091, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.05 channel size 64 train accuracy: tensor(0.1096, device='cuda:0') validation accuracy: 0.10658333333333334
# lr: 0.05 channel size 128 train accuracy: tensor(0.1104, device='cuda:0') validation accuracy: 0.10658333333333334
# lr: 0.05 channel size 256 train accuracy: tensor(0.1090, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.01 channel size 32 train accuracy: tensor(0.1123, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.01 channel size 64 train accuracy: tensor(0.9350, device='cuda:0') validation accuracy: 0.9074166666666666
# lr: 0.01 channel size 128 train accuracy: tensor(0.6887, device='cuda:0') validation accuracy: 0.6939166666666666
# lr: 0.01 channel size 256 train accuracy: tensor(0.1120, device='cuda:0') validation accuracy: 0.11266666666666666
# lr: 0.01 channel size 32 train accuracy: tensor(0.9590, device='cuda:0') validation accuracy: 0.9508333333333333
# lr: 0.01 channel size 64 train accuracy: tensor(0.9518, device='cuda:0') validation accuracy: 0.9335833333333333
# lr: 0.01 channel size 128 train accuracy: tensor(0.9610, device='cuda:0') validation accuracy: 0.9411666666666667
# lr: 0.01 channel size 256 train accuracy: tensor(0.1123, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.01 channel size 32 train accuracy: tensor(0.8684, device='cuda:0') validation accuracy: 0.8626666666666667
# lr: 0.01 channel size 64 train accuracy: tensor(0.1123, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.01 channel size 128 train accuracy: tensor(0.1124, device='cuda:0') validation accuracy: 0.11266666666666666
# lr: 0.01 channel size 256 train accuracy: tensor(0.9476, device='cuda:0') validation accuracy: 0.9419166666666666
# lr: 0.01 channel size 32 train accuracy: tensor(0.9606, device='cuda:0') validation accuracy: 0.9565833333333333
# lr: 0.01 channel size 64 train accuracy: tensor(0.9300, device='cuda:0') validation accuracy: 0.9239166666666667
# lr: 0.01 channel size 128 train accuracy: tensor(0.9404, device='cuda:0') validation accuracy: 0.9363333333333334
# lr: 0.01 channel size 256 train accuracy: tensor(0.9771, device='cuda:0') validation accuracy: 0.9535833333333333
# lr: 0.01 channel size 32 train accuracy: tensor(0.1123, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.01 channel size 64 train accuracy: tensor(0.9700, device='cuda:0') validation accuracy: 0.9520833333333333
# lr: 0.01 channel size 128 train accuracy: tensor(0.9850, device='cuda:0') validation accuracy: 0.95925
# lr: 0.01 channel size 256 train accuracy: tensor(0.9810, device='cuda:0') validation accuracy: 0.9520833333333333
# lr: 0.005 channel size 32 train accuracy: tensor(0.9440, device='cuda:0') validation accuracy: 0.9446666666666667
# lr: 0.005 channel size 64 train accuracy: tensor(0.6890, device='cuda:0') validation accuracy: 0.7049166666666666
# lr: 0.005 channel size 128 train accuracy: tensor(0.9003, device='cuda:0') validation accuracy: 0.8735
# lr: 0.005 channel size 256 train accuracy: tensor(0.1123, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.005 channel size 32 train accuracy: tensor(0.9347, device='cuda:0') validation accuracy: 0.9235
# lr: 0.005 channel size 64 train accuracy: tensor(0.9783, device='cuda:0') validation accuracy: 0.96
# lr: 0.005 channel size 128 train accuracy: tensor(0.9682, device='cuda:0') validation accuracy: 0.9555833333333333
# lr: 0.005 channel size 256 train accuracy: tensor(0.9819, device='cuda:0') validation accuracy: 0.9633333333333334
# lr: 0.005 channel size 32 train accuracy: tensor(0.9656, device='cuda:0') validation accuracy: 0.9531666666666667
# lr: 0.005 channel size 64 train accuracy: tensor(0.9744, device='cuda:0') validation accuracy: 0.9610833333333333
# lr: 0.005 channel size 128 train accuracy: tensor(0.9875, device='cuda:0') validation accuracy: 0.9693333333333334
# lr: 0.005 channel size 256 train accuracy: tensor(0.9845, device='cuda:0') validation accuracy: 0.9671666666666666
# lr: 0.005 channel size 32 train accuracy: tensor(0.9894, device='cuda:0') validation accuracy: 0.9706666666666667
# lr: 0.005 channel size 64 train accuracy: tensor(0.9771, device='cuda:0') validation accuracy: 0.9595
# lr: 0.005 channel size 128 train accuracy: tensor(0.9935, device='cuda:0') validation accuracy: 0.9756666666666667
# lr: 0.005 channel size 256 train accuracy: tensor(0.9910, device='cuda:0') validation accuracy: 0.9694166666666667
# lr: 0.005 channel size 32 train accuracy: tensor(0.9910, device='cuda:0') validation accuracy: 0.9721666666666666
# lr: 0.005 channel size 64 train accuracy: tensor(0.9959, device='cuda:0') validation accuracy: 0.9785
# lr: 0.005 channel size 128 train accuracy: tensor(0.9845, device='cuda:0') validation accuracy: 0.96325
# lr: 0.005 channel size 256 train accuracy: tensor(0.9969, device='cuda:0') validation accuracy: 0.9719166666666667
# lr: 0.001 channel size 32 train accuracy: tensor(0.1123, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.001 channel size 64 train accuracy: tensor(0.8617, device='cuda:0') validation accuracy: 0.87825
# lr: 0.001 channel size 128 train accuracy: tensor(0.1123, device='cuda:0') validation accuracy: 0.11258333333333333
# lr: 0.001 channel size 256 train accuracy: tensor(0.9478, device='cuda:0') validation accuracy: 0.92075
# lr: 0.001 channel size 32 train accuracy: tensor(0.9925, device='cuda:0') validation accuracy: 0.974
# lr: 0.001 channel size 64 train accuracy: tensor(0.9979, device='cuda:0') validation accuracy: 0.97825
# lr: 0.001 channel size 128 train accuracy: tensor(0.9937, device='cuda:0') validation accuracy: 0.9720833333333333
# lr: 0.001 channel size 256 train accuracy: tensor(0.9997, device='cuda:0') validation accuracy: 0.9793333333333333
# lr: 0.001 channel size 32 train accuracy: tensor(0.9975, device='cuda:0') validation accuracy: 0.9784166666666667
# lr: 0.001 channel size 64 train accuracy: tensor(0.9974, device='cuda:0') validation accuracy: 0.97675
# lr: 0.001 channel size 128 train accuracy: tensor(0.9998, device='cuda:0') validation accuracy: 0.9819166666666667
# lr: 0.001 channel size 256 train accuracy: tensor(0.9999, device='cuda:0') validation accuracy: 0.9796666666666667
# lr: 0.001 channel size 32 train accuracy: tensor(0.9995, device='cuda:0') validation accuracy: 0.9805833333333334
# lr: 0.001 channel size 64 train accuracy: tensor(1.0000, device='cuda:0') validation accuracy: 0.98375
# lr: 0.001 channel size 128 train accuracy: tensor(0.9999, device='cuda:0') validation accuracy: 0.982
# lr: 0.001 channel size 256 train accuracy: tensor(1., device='cuda:0') validation accuracy: 0.9826666666666667
# lr: 0.001 channel size 32 train accuracy: tensor(1., device='cuda:0') validation accuracy: 0.9834166666666667
# lr: 0.001 channel size 64 train accuracy: tensor(1., device='cuda:0') validation accuracy: 0.98375
# lr: 0.001 channel size 128 train accuracy: tensor(1., device='cuda:0') validation accuracy: 0.9850833333333333
# lr: 0.001 channel size 256 train accuracy: tensor(1., device='cuda:0') validation accuracy: 0.9844166666666667
